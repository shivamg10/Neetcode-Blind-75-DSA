# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 1) Brute Force --- TC : O(N^2), SC: O(1)

# %% [markdown]
# Generate all possible combinations then take the max Profit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 2) Keep Updating Low Price --- TC: O(N), SC : O(1)

# %% [markdown]
# Check if you current price is lower than min price, if it is then just update min otherwise find profit and update maxProfit.

# %% [markdown]
# ![image.png](attachment:image.png)
