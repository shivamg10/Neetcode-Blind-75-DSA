# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Solution 1) Creating a New Alphanumeric String and Comparing it with the reversed String --TC : O(N) , SC : O(N)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Soultion 2) Using the 2 pointer Approach -- TC : O(N) , SC  : O(1)

# %% [markdown]
# ![image.png](attachment:image.png)
